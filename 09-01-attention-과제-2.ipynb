# %% [markdown]
# # Install

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 9.9MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95

# %% [markdown]
# # Evn

# %%
import os
import random
import shutil
import json
import zipfile
import math
import copy
import collections
import re

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sentencepiece as spm
import tensorflow as tf
import tensorflow.keras.backend as KK

from tqdm.notebook import tqdm

# %%
# random seed initialize
random_seed = 1234
random.seed(random_seed)
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# %%
# !nvidia-smi
# Out:
# Mon Feb  8 05:41:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data dir
data_dir = '/content/drive/MyDrive/HUFS_AIcamp/data'
os.listdir(data_dir)
# Out:
# ['ko_32000.model', 'ko_32000.vocab', 'kowiki', 'nsmc', 'quora', 'songys']

# %%
# songys chatbot dir
songys_dir = os.path.join(data_dir, 'songys')
if not os.path.exists(songys_dir):
    os.makedirs(songys_dir)
os.listdir(songys_dir)
# Out:
# ['ChatbotData.csv', 'lstm.csv', 'lstm.hdf5', 'lstm_dot.hdf5', 'lstm_dot.csv']

# %% [markdown]
# # Attention

# %%
def get_pad_mask(tokens, i_pad=0):
    """
    pad mask 계산하는 함수
    :param tokens: tokens (bs, n_seq)
    :param i_pad: id of pad
    :return mask: pad mask (pad: 1, other: 0)
    """
    # 0인 부분 확인
    mask = tf.math.equal(tokens, i_pad)
    # boolean -> float 32
    mask = tf.cast(mask, tf.float32)
    # expand dimension for n_seq
    mask = tf.expand_dims(mask, axis=1)
    return mask

# %%
class ScaleDotProductAttention(tf.keras.layers.Layer):
    """
    Scale Dot Product Attention Class
    """
    def __init__(self, name="scale_dot_product_attention"):
        """
        생성자
        :param name: layer name
        """
        super().__init__(name=name)

    def call(self, inputs):
        """
        layer 실행
        :param inputs: Q, K, V, attn_mask tuple
        :return attn_out: attention 실행 결과
        """
        Q, K, V, attn_mask = inputs
        # matmul Q, K (transpose_b=True)
        attn_score = tf.matmul(Q, K, transpose_b=True)
        # get scale = d_model ** 0.5
        scale = tf.math.sqrt(tf.cast(tf.shape(K)[-1], tf.float32))
        # divide by scale
        attn_scale = tf.math.divide(attn_score, scale)
        # do mask (subtract 1e-9 for masked value)
        attn_scale -= 1.e9 * attn_mask
        # calculate attention prob
        attn_prob = tf.nn.softmax(attn_scale, axis=-1)
        # weighted sum of V
        attn_out = tf.matmul(attn_prob, V)
        return attn_out

# %%
attention = ScaleDotProductAttention()
attention((Q, K, V, attn_mask))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8b69cc20033e> in <module>()
#       1 attention = ScaleDotProductAttention()
# ----> 2 attention((Q, K, V, attn_mask))
#
# NameError: name 'Q' is not defined

# %% [markdown]
# # Vocabulary & config

# %%
# vocab loading
vocab = spm.SentencePieceProcessor()
vocab.load(os.path.join(data_dir, 'ko_32000.model'))
# Out:
# True

# %%
n_vocab = len(vocab)  # number of vocabulary
n_enc_seq = 32  # number of sequence 1
n_dec_seq = 40  # number of sequence 2
d_model = 256  # dimension of model

# %% [markdown]
# # 모델링

# %%
def build_model(n_vocab, d_model, n_enc_seq, n_dec_seq):
    """
    문장 유사도 비교 모델
    :param n_vocab: vocabulary 단어 수
    :param d_model: 단어를 의미하는 벡터의 차원 수
    :param n_enc_seq: encoder 문장 길이 (단어 수)
    :param n_dec_seq: decoder 문장 길이 (단어 수)
    """
    inputs_enc = tf.keras.layers.Input((n_enc_seq,))  # (bs, n_enc_seq)
    inputs_dec = tf.keras.layers.Input((n_dec_seq,))  # (bs, n_dec_seq)
    # pad mask 생성
    ###############################################
    attn_mask = get_pad_mask(inputs_enc)
    ###############################################
    # 입력 단어를 vector로 변환
    embedding = tf.keras.layers.Embedding(n_vocab, d_model)
    hidden_enc = embedding(inputs_enc)  # (bs, n_enc_seq, d_model)
    hidden_dec = embedding(inputs_dec)  # (bs, n_dec_seq, d_model)
    # encoder LSTM
    fw_cell = tf.keras.layers.LSTM(units=d_model, return_sequences=True, return_state=True)
    bw_cell = tf.keras.layers.LSTM(units=d_model, go_backwards=True, return_sequences=True, return_state=True)
    lstm_enc = tf.keras.layers.Bidirectional(fw_cell, backward_layer=bw_cell)
    hidden_enc, fw_h, fw_c, bw_h, bw_c = lstm_enc(hidden_enc)  # (bs, n_enc_seq, d_model * 2), (bs, d_model), (bs, d_model), (bs, d_model), (bs, d_model)
    # concat hidden & cell
    s_h = tf.concat([fw_h, bw_h], axis=-1)  # (bs, d_model * 2)
    s_c = tf.concat([fw_c, bw_c], axis=-1)  # (bs, d_model * 2)
    # decoder LSTM
    lstm_dec = tf.keras.layers.LSTM(units=d_model * 2, return_sequences=True)
    hidden_dec = lstm_dec(hidden_dec, initial_state=[s_h, s_c])  # (bs, n_dec_seq, d_model)
    # ScaleDotProductAttention 실행
    ##############################################
    attention = ScaleDotProductAttention()
    attn_out = attention((hidden_dec, hidden_enc, hidden_enc, attn_mask))
    ##############################################
    # concat output
    dec_out = tf.concat([attn_out, hidden_dec], axis=-1)
    # 다음단어 예측
    dense_out = tf.keras.layers.Dense(units=n_vocab, activation=tf.nn.softmax)
    outputs = dense_out(dec_out)  # (bs, n_dec_seq, n_vocab)
    # 학습할 모델 선언
    model = tf.keras.Model(inputs=(inputs_enc, inputs_dec), outputs=outputs)
    return model

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %% [markdown]
# # Loss & Acc

# %%
def lm_loss(y_true, y_pred):
    """
    pad 부분을 제외하고 loss를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 loss 값
    """
    # loss = sparse_entropy = tf.keras.losses.SparseCategoricalCrossentropy()(y_true, y_pred)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)(y_true, y_pred)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    loss *= mask
    return loss

# %%
def lm_acc(y_true, y_pred):
    """
    pad 부분을 제외하고 accuracy를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 accuracy 값
    """
    y_true = tf.cast(y_true, tf.float32)
    # print(y_true)
    y_pred_class = tf.cast(tf.argmax(y_pred, axis=-1), tf.float32)
    # print(y_pred_class)
    matches = tf.cast(tf.equal(y_true, y_pred_class), tf.float32)
    # print(matches)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    matches *= mask
    # print(matches)
    # accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(tf.ones_like(matches)), 1)
    accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(mask), 1)
    return accuracy

# %% [markdown]
# # All Data Project

# %% [markdown]
# ## Data

# %%
df_train = pd.read_csv(os.path.join(songys_dir, 'ChatbotData.csv'))
print(len(df_train))
df_train = df_train.dropna()
print(len(df_train))
df_train
# Out:
# 11823
# 11823
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.      0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.      0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.      0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.      0
# 4                      PPL 심하네                눈살이 찌푸려지죠.      0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2
#
# [11823 rows x 3 columns]

# %%
def load_data(df, n_enc_seq, n_dec_seq):
    """
    Quora 학습 데이터 생성
    :param df: data frame
    :param n_enc_seq: number of encoder sequence
    :param n_dec_seq: number of decoder sequence
    :return enc_inputs: encoder input data
    :return dec_inputs: decoder input data
    :return labels: label data
    """
    n_enc_max = n_enc_seq
    n_dec_max = n_dec_seq - 1
    enc_inputs = np.zeros((len(df), n_enc_seq)).astype(np.int32)
    dec_inputs = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    labels = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    index = 0
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # tokens 저장
        Q = row['Q']
        A = row['A']

        tokens_q = vocab.encode_as_pieces(Q)
        tokens_a = vocab.encode_as_pieces(A)

        tokens_ids_q = vocab.encode_as_ids(Q)[:n_enc_max]
        tokens_ids_a = vocab.encode_as_ids(A)[:n_dec_max]

        tokens_dec_in = [vocab.bos_id()] + tokens_ids_a
        tokens_dec_out = tokens_ids_a + [vocab.eos_id()]

        tokens_ids_q += [0] * (n_enc_seq - len(tokens_ids_q))
        tokens_dec_in += [0] * (n_dec_seq - len(tokens_dec_in))
        tokens_dec_out += [0] * (n_dec_seq - len(tokens_dec_out))

        enc_inputs[index] = tokens_ids_q
        dec_inputs[index] = tokens_dec_in
        labels[index] = tokens_dec_out
        index += 1
    return enc_inputs, dec_inputs, labels

# %%
# train data 생성
train_enc_inputs, train_dec_inputs, train_labels = load_data(df_train, n_enc_seq, n_dec_seq)
train_enc_inputs, train_dec_inputs, train_labels
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11823.0), HTML(value='')))
# (array([[   89,    56,    10, ...,     0,     0,     0],
#         [   35,    47,  1004, ...,     0,     0,     0],
#         [   38,   819,   362, ...,     0,     0,     0],
#         ...,
#         [ 2886,  9525, 21930, ...,     0,     0,     0],
#         [10736,  8256,  1172, ...,     0,     0,     0],
#         [26128,    70,  1381, ...,     0,     0,     0]], dtype=int32),
#  array([[    2,  2261,    19, ...,     0,     0,     0],
#         [    2,  4594,    61, ...,     0,     0,     0],
#         [    2,  2350,    18, ...,     0,     0,     0],
#         ...,
#         [    2,  1522,     1, ...,     0,     0,     0],
#         [    2,   441, 10316, ...,     0,     0,     0],
#         [    2, 16665,    90, ...,     0,     0,     0]], dtype=int32),
#  array([[ 2261,    19,   375, ...,     0,     0,     0],
#         [ 4594,    61,   929, ...,     0,     0,     0],
#         [ 2350,    18,  9001, ...,     0,     0,     0],
#         ...,
#         [ 1522,     1, 12273, ...,     0,     0,     0],
#         [  441, 10316,   515, ...,     0,     0,     0],
#         [16665,    90,  1381, ...,     0,     0,     0]], dtype=int32))

# %% [markdown]
# ## 학습

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %%
# 모델 loss, optimizer, metric 정의
model.compile(loss=lm_loss, optimizer='adam', metrics=[lm_acc])

# %%
# early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='lm_acc', patience=5)
# save weights callback
save_weights = tf.keras.callbacks.ModelCheckpoint(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'),
                                                  monitor='lm_acc',
                                                  verbose=1,
                                                  save_best_only=True,
                                                  mode="max",
                                                  save_freq="epoch",
                                                  save_weights_only=True)
# csv logger
csv_logger = tf.keras.callbacks.CSVLogger(os.path.join(songys_dir, 'lstm_scale_dot.csv'))

# %%
# 모델 학습
history = model.fit((train_enc_inputs, train_dec_inputs),
                    train_labels,
                    epochs=100,
                    batch_size=256,
                    callbacks=[early_stopping, save_weights, csv_logger])
# Out:
# Epoch 1/100
# 47/47 [==============================] - 29s 504ms/step - loss: 1.8909 - lm_acc: 0.1160
#
# Epoch 00001: lm_acc improved from -inf to 0.11987, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 2/100
# 47/47 [==============================] - 24s 507ms/step - loss: 1.2921 - lm_acc: 0.1437
#
# Epoch 00002: lm_acc improved from 0.11987 to 0.16453, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 3/100
# 47/47 [==============================] - 24s 506ms/step - loss: 1.1786 - lm_acc: 0.2492
#
# Epoch 00003: lm_acc improved from 0.16453 to 0.26637, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 4/100
# 47/47 [==============================] - 24s 507ms/step - loss: 1.0948 - lm_acc: 0.2856
#
# Epoch 00004: lm_acc improved from 0.26637 to 0.29206, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 5/100
# 47/47 [==============================] - 24s 506ms/step - loss: 1.0403 - lm_acc: 0.3208
#
# Epoch 00005: lm_acc improved from 0.29206 to 0.32916, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 6/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.9849 - lm_acc: 0.3477
#
# Epoch 00006: lm_acc improved from 0.32916 to 0.35147, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 7/100
# 47/47 [==============================] - 24s 508ms/step - loss: 0.9415 - lm_acc: 0.3651
#
# Epoch 00007: lm_acc improved from 0.35147 to 0.37098, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 8/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.8930 - lm_acc: 0.3850
#
# Epoch 00008: lm_acc improved from 0.37098 to 0.38836, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 9/100
# 47/47 [==============================] - 24s 507ms/step - loss: 0.8528 - lm_acc: 0.3991
#
# Epoch 00009: lm_acc improved from 0.38836 to 0.40158, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 10/100
# 47/47 [==============================] - 24s 508ms/step - loss: 0.8204 - lm_acc: 0.4142
#
# Epoch 00010: lm_acc improved from 0.40158 to 0.41452, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 11/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.7875 - lm_acc: 0.4252
#
# Epoch 00011: lm_acc improved from 0.41452 to 0.42583, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 12/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.7551 - lm_acc: 0.4365
#
# Epoch 00012: lm_acc improved from 0.42583 to 0.43759, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 13/100
# 47/47 [==============================] - 24s 507ms/step - loss: 0.7258 - lm_acc: 0.4504
#
# Epoch 00013: lm_acc improved from 0.43759 to 0.44928, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 14/100
# 47/47 [==============================] - 24s 507ms/step - loss: 0.7091 - lm_acc: 0.4578
#
# Epoch 00014: lm_acc improved from 0.44928 to 0.46106, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 15/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.6747 - lm_acc: 0.4738
#
# Epoch 00015: lm_acc improved from 0.46106 to 0.47434, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 16/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.6433 - lm_acc: 0.4885
#
# Epoch 00016: lm_acc improved from 0.47434 to 0.48597, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 17/100
# 47/47 [==============================] - 24s 508ms/step - loss: 0.6253 - lm_acc: 0.4980
#
# Epoch 00017: lm_acc improved from 0.48597 to 0.49783, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 18/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.6096 - lm_acc: 0.5090
#
# Epoch 00018: lm_acc improved from 0.49783 to 0.50907, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 19/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.5815 - lm_acc: 0.5272
#
# Epoch 00019: lm_acc improved from 0.50907 to 0.52548, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 20/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.5549 - lm_acc: 0.5420
#
# Epoch 00020: lm_acc improved from 0.52548 to 0.54012, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 21/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.5316 - lm_acc: 0.5582
#
# Epoch 00021: lm_acc improved from 0.54012 to 0.55461, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 22/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.5122 - lm_acc: 0.5715
#
# Epoch 00022: lm_acc improved from 0.55461 to 0.56796, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 23/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.4987 - lm_acc: 0.5813
#
# Epoch 00023: lm_acc improved from 0.56796 to 0.57693, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 24/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.4815 - lm_acc: 0.5921
#
# Epoch 00024: lm_acc improved from 0.57693 to 0.59050, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 25/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.4627 - lm_acc: 0.6051
#
# Epoch 00025: lm_acc improved from 0.59050 to 0.60596, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 26/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.4381 - lm_acc: 0.6249
#
# Epoch 00026: lm_acc improved from 0.60596 to 0.61987, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 27/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.4186 - lm_acc: 0.6378
#
# Epoch 00027: lm_acc improved from 0.61987 to 0.63297, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 28/100
# 47/47 [==============================] - 23s 500ms/step - loss: 0.4038 - lm_acc: 0.6487
#
# Epoch 00028: lm_acc improved from 0.63297 to 0.64551, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 29/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.3901 - lm_acc: 0.6617
#
# Epoch 00029: lm_acc improved from 0.64551 to 0.65896, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 30/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.3717 - lm_acc: 0.6746
#
# Epoch 00030: lm_acc improved from 0.65896 to 0.67182, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 31/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.3578 - lm_acc: 0.6888
#
# Epoch 00031: lm_acc improved from 0.67182 to 0.68576, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 32/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.3419 - lm_acc: 0.7000
#
# Epoch 00032: lm_acc improved from 0.68576 to 0.69607, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 33/100
# 47/47 [==============================] - 24s 500ms/step - loss: 0.3293 - lm_acc: 0.7093
#
# Epoch 00033: lm_acc improved from 0.69607 to 0.70784, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 34/100
# 47/47 [==============================] - 23s 499ms/step - loss: 0.3127 - lm_acc: 0.7243
#
# Epoch 00034: lm_acc improved from 0.70784 to 0.72109, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 35/100
# 47/47 [==============================] - 23s 499ms/step - loss: 0.2976 - lm_acc: 0.7354
#
# Epoch 00035: lm_acc improved from 0.72109 to 0.73296, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 36/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.2861 - lm_acc: 0.7471
#
# Epoch 00036: lm_acc improved from 0.73296 to 0.74437, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 37/100
# 47/47 [==============================] - 23s 500ms/step - loss: 0.2704 - lm_acc: 0.7594
#
# Epoch 00037: lm_acc improved from 0.74437 to 0.75452, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 38/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.2604 - lm_acc: 0.7720
#
# Epoch 00038: lm_acc improved from 0.75452 to 0.76596, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 39/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.2478 - lm_acc: 0.7823
#
# Epoch 00039: lm_acc improved from 0.76596 to 0.77776, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 40/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.2351 - lm_acc: 0.7948
#
# Epoch 00040: lm_acc improved from 0.77776 to 0.78713, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 41/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.2246 - lm_acc: 0.8039
#
# Epoch 00041: lm_acc improved from 0.78713 to 0.79812, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 42/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.2160 - lm_acc: 0.8120
#
# Epoch 00042: lm_acc improved from 0.79812 to 0.80875, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 43/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.2046 - lm_acc: 0.8220
#
# Epoch 00043: lm_acc improved from 0.80875 to 0.81795, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 44/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.1932 - lm_acc: 0.8337
#
# Epoch 00044: lm_acc improved from 0.81795 to 0.82768, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 45/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.1863 - lm_acc: 0.8406
#
# Epoch 00045: lm_acc improved from 0.82768 to 0.83613, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 46/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.1775 - lm_acc: 0.8484
#
# Epoch 00046: lm_acc improved from 0.83613 to 0.84554, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 47/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.1693 - lm_acc: 0.8576
#
# Epoch 00047: lm_acc improved from 0.84554 to 0.85395, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 48/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.1606 - lm_acc: 0.8662
#
# Epoch 00048: lm_acc improved from 0.85395 to 0.86248, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 49/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.1505 - lm_acc: 0.8755
#
# Epoch 00049: lm_acc improved from 0.86248 to 0.87248, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 50/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.1426 - lm_acc: 0.8838
#
# Epoch 00050: lm_acc improved from 0.87248 to 0.87964, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 51/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.1372 - lm_acc: 0.8895
#
# Epoch 00051: lm_acc improved from 0.87964 to 0.88261, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 52/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.1338 - lm_acc: 0.8927
#
# Epoch 00052: lm_acc improved from 0.88261 to 0.89049, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 53/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.1239 - lm_acc: 0.9031
#
# Epoch 00053: lm_acc improved from 0.89049 to 0.90089, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 54/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.1182 - lm_acc: 0.9062
#
# Epoch 00054: lm_acc improved from 0.90089 to 0.90194, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 55/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.1115 - lm_acc: 0.9150
#
# Epoch 00055: lm_acc improved from 0.90194 to 0.91286, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 56/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.1046 - lm_acc: 0.9207
#
# Epoch 00056: lm_acc improved from 0.91286 to 0.91668, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 57/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.1001 - lm_acc: 0.9254
#
# Epoch 00057: lm_acc improved from 0.91668 to 0.92101, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 58/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0963 - lm_acc: 0.9294
#
# Epoch 00058: lm_acc improved from 0.92101 to 0.92835, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 59/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0892 - lm_acc: 0.9374
#
# Epoch 00059: lm_acc improved from 0.92835 to 0.93447, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 60/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0834 - lm_acc: 0.9424
#
# Epoch 00060: lm_acc improved from 0.93447 to 0.93950, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 61/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0792 - lm_acc: 0.9471
#
# Epoch 00061: lm_acc improved from 0.93950 to 0.94553, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 62/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0743 - lm_acc: 0.9513
#
# Epoch 00062: lm_acc improved from 0.94553 to 0.94984, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 63/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0703 - lm_acc: 0.9551
#
# Epoch 00063: lm_acc improved from 0.94984 to 0.95319, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 64/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0681 - lm_acc: 0.9575
#
# Epoch 00064: lm_acc improved from 0.95319 to 0.95554, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 65/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0634 - lm_acc: 0.9617
#
# Epoch 00065: lm_acc improved from 0.95554 to 0.95945, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 66/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.0589 - lm_acc: 0.9656
#
# Epoch 00066: lm_acc improved from 0.95945 to 0.96293, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 67/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0567 - lm_acc: 0.9668
#
# Epoch 00067: lm_acc improved from 0.96293 to 0.96361, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 68/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0569 - lm_acc: 0.9668
#
# Epoch 00068: lm_acc improved from 0.96361 to 0.96579, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 69/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0506 - lm_acc: 0.9722
#
# Epoch 00069: lm_acc improved from 0.96579 to 0.96976, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 70/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.0492 - lm_acc: 0.9738
#
# Epoch 00070: lm_acc improved from 0.96976 to 0.97332, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 71/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0449 - lm_acc: 0.9778
#
# Epoch 00071: lm_acc improved from 0.97332 to 0.97582, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 72/100
# 47/47 [==============================] - 24s 505ms/step - loss: 0.0455 - lm_acc: 0.9751
#
# Epoch 00072: lm_acc did not improve from 0.97582
# Epoch 73/100
# 47/47 [==============================] - 23s 499ms/step - loss: 0.0413 - lm_acc: 0.9800
#
# Epoch 00073: lm_acc improved from 0.97582 to 0.97959, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 74/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0362 - lm_acc: 0.9840
#
# Epoch 00074: lm_acc improved from 0.97959 to 0.98249, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 75/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0352 - lm_acc: 0.9846
#
# Epoch 00075: lm_acc improved from 0.98249 to 0.98456, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 76/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0316 - lm_acc: 0.9874
#
# Epoch 00076: lm_acc improved from 0.98456 to 0.98580, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 77/100
# 47/47 [==============================] - 23s 499ms/step - loss: 0.0301 - lm_acc: 0.9878
#
# Epoch 00077: lm_acc improved from 0.98580 to 0.98726, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 78/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0280 - lm_acc: 0.9900
#
# Epoch 00078: lm_acc improved from 0.98726 to 0.98933, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 79/100
# 47/47 [==============================] - 24s 506ms/step - loss: 0.0263 - lm_acc: 0.9913
#
# Epoch 00079: lm_acc improved from 0.98933 to 0.98978, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 80/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0264 - lm_acc: 0.9910
#
# Epoch 00080: lm_acc improved from 0.98978 to 0.99015, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 81/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0242 - lm_acc: 0.9926
#
# Epoch 00081: lm_acc improved from 0.99015 to 0.99220, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 82/100
# 47/47 [==============================] - 24s 500ms/step - loss: 0.0295 - lm_acc: 0.9860
#
# Epoch 00082: lm_acc did not improve from 0.99220
# Epoch 83/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0315 - lm_acc: 0.9855
#
# Epoch 00083: lm_acc did not improve from 0.99220
# Epoch 84/100
# 47/47 [==============================] - 23s 500ms/step - loss: 0.0245 - lm_acc: 0.9924
#
# Epoch 00084: lm_acc did not improve from 0.99220
# Epoch 85/100
# 47/47 [==============================] - 23s 499ms/step - loss: 0.0210 - lm_acc: 0.9940
#
# Epoch 00085: lm_acc improved from 0.99220 to 0.99315, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 86/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0193 - lm_acc: 0.9947
#
# Epoch 00086: lm_acc improved from 0.99315 to 0.99471, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 87/100
# 47/47 [==============================] - 24s 503ms/step - loss: 0.0168 - lm_acc: 0.9962
#
# Epoch 00087: lm_acc improved from 0.99471 to 0.99525, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 88/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0160 - lm_acc: 0.9966
#
# Epoch 00088: lm_acc improved from 0.99525 to 0.99599, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 89/100
# 47/47 [==============================] - 24s 504ms/step - loss: 0.0151 - lm_acc: 0.9966
#
# Epoch 00089: lm_acc did not improve from 0.99599
# Epoch 90/100
# 47/47 [==============================] - 24s 500ms/step - loss: 0.0142 - lm_acc: 0.9971
#
# Epoch 00090: lm_acc improved from 0.99599 to 0.99675, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 91/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0126 - lm_acc: 0.9978
#
# Epoch 00091: lm_acc improved from 0.99675 to 0.99723, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 92/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0121 - lm_acc: 0.9978
#
# Epoch 00092: lm_acc improved from 0.99723 to 0.99743, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 93/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0113 - lm_acc: 0.9980
#
# Epoch 00093: lm_acc improved from 0.99743 to 0.99773, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 94/100
# 47/47 [==============================] - 24s 502ms/step - loss: 0.0106 - lm_acc: 0.9981
#
# Epoch 00094: lm_acc did not improve from 0.99773
# Epoch 95/100
# 47/47 [==============================] - 23s 499ms/step - loss: 0.0099 - lm_acc: 0.9983
#
# Epoch 00095: lm_acc improved from 0.99773 to 0.99808, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 96/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0093 - lm_acc: 0.9986
#
# Epoch 00096: lm_acc improved from 0.99808 to 0.99834, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 97/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0088 - lm_acc: 0.9983
#
# Epoch 00097: lm_acc did not improve from 0.99834
# Epoch 98/100
# 47/47 [==============================] - 23s 498ms/step - loss: 0.0082 - lm_acc: 0.9986
#
# Epoch 00098: lm_acc improved from 0.99834 to 0.99836, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 99/100
# 47/47 [==============================] - 24s 501ms/step - loss: 0.0081 - lm_acc: 0.9985
#
# Epoch 00099: lm_acc improved from 0.99836 to 0.99838, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5
# Epoch 100/100
# 47/47 [==============================] - 23s 499ms/step - loss: 0.0076 - lm_acc: 0.9987
#
# Epoch 00100: lm_acc improved from 0.99838 to 0.99851, saving model to /content/drive/MyDrive/HUFS_AIcamp/data/songys/lstm_scale_dot.hdf5

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['lm_acc'], 'g-', label='acc')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %% [markdown]
# ## Inference

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# train weight로 초기화
model.load_weights(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'))

# %%
def do_chat(vocab, model, n_enc_seq, n_dec_seq, string):
    """
    seq2seq chat
    :param vocab: vocab
    :param model: model
    :param n_enc_seq: number of enc seqence
    :param n_dec_seq: number of dec seqence
    :param string: inpust string
    """
    # qeustion
    q = vocab.encode_as_pieces(string)
    q_id = [vocab.piece_to_id(p) for p in q][:n_enc_seq]
    q_id += [0] * (n_enc_seq - len(q_id))
    assert len(q_id) == n_enc_seq

    # answer
    a_id = [vocab.bos_id()]
    a_id += [0] * (n_dec_seq - len(a_id))
    assert len(a_id) == n_dec_seq

    # 처음부터 예측
    start_idx = 0

    for _ in range(start_idx, n_dec_seq - 1):
        outputs = model.predict((np.array([q_id]), np.array([a_id])))
        prob = outputs[0][start_idx]
        word_id = np.argmax(prob)
        if word_id == vocab.eos_id():
            break
        a_id[start_idx + 1] = int(word_id)
        start_idx += 1
    predict_id = a_id[1:start_idx + 1]
    predict_str = vocab.decode_ids(predict_id)
    return predict_str

# %%
while True:
    string = input('질문 > ')
    string = string.strip()
    if len(string) == 0:
        break
    predict_str = do_chat(vocab, model, n_enc_seq, n_dec_seq, string)
    print(f'답변 > {predict_str}')
# Out:
# 질문 > 안녕하세요
# 답변 > 안녕하세요.
# 질문 > 뭐해 ?
# 답변 > 저도요.
# 질문 > 뭐하는 중이야?
# 답변 > 아직은 괜찮아요.
# 질문 > 무슨 일이야?
# 답변 > 다 알 수는 없어요.
# 질문 > 집에 가고 싶어
# 답변 > 집안 분위기가 바뀔 거예요.
# 질문 > 지금 집안 분위기 어때 ?
# 답변 > 저도 좋아해요.
# 질문 > 맛있는 음식이 뭐야?
# 답변 > 정말 예쁘게 하는지 하겠죠.
# 질문 > 그래
# 답변 > 좋은 생각이네요.
# 질문 >
